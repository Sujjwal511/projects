# %%
#To predict tmrw it will rain or not in australia.
import pandas as pd     
import numpy as np    
import seaborn as sns  
import matplotlib.pyplot as plt 
# %matplotlib inline

df = pd.read_csv('AustraliaWeather.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#description of dataset
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
#shape of the dataset
df.shape
# Out:
# (145460, 23)

# %%
#information ofthe dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
#checking for null values
df.isnull()
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       False     False    False    False     False         True      True
# 1       False     False    False    False     False         True      True
# 2       False     False    False    False     False         True      True
# 3       False     False    False    False     False         True      True
# 4       False     False    False    False     False         True      True
# ...       ...       ...      ...      ...       ...          ...       ...
# 145455  False     False    False    False     False         True      True
# 145456  False     False    False    False     False         True      True
# 145457  False     False    False    False     False         True      True
# 145458  False     False    False    False     False         True      True
# 145459  False     False    False     True     False         True      True
#
# ...

# %%
#to check how many null values are there in column
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
#dropping the columns which we dont need.
df=df.drop(['Evaporation','Evaporation','Cloud9am','Cloud3pm','Location','Date'], axis=1)
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Sunshine WindGustDir  WindGustSpeed WindDir9am  \
# 0     13.4     22.9       0.6       NaN           W           44.0          W
# 1      7.4     25.1       0.0       NaN         WNW           44.0        NNW
# 2     12.9     25.7       0.0       NaN         WSW           46.0          W
# 3      9.2     28.0       0.0       NaN          NE           24.0         SE
# 4     17.5     32.3       1.0       NaN           W           41.0        ENE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday RainTomorrow
# ...

# %%
#dropping the rows in the dataset which has null values.
df=df.dropna(axis=0)
df.shape
# Out:
# (66646, 18)

# %%
#name of the columns in dataset in which raintmrw wich need to be predicted.
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Sunshine', 'WindGustDir',
#        'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Temp9am', 'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
#by using label encoding we need to convert string into numerical data.
from sklearn.preprocessing import LabelEncoder #imprted labelencoder from sklear.preprocessing
le = LabelEncoder()                            #
df['WindGustDir']=le.fit_transform(df['WindGustDir']) #transform into numerical and store in ame column.
df['WindDir9am']=le.fit_transform(df['WindDir9am'])    #
df['WindDir3pm']=le.fit_transform(df['WindDir3pm'])     #
df['RainToday']=le.fit_transform(df['RainToday'])       #
df['RainTomorrow']=le.fit_transform(df['RainTomorrow'])   #

# %%
df.head()
# Out:
#       MinTemp  MaxTemp  Rainfall  Sunshine  WindGustDir  WindGustSpeed  \
# 6049     17.9     35.2       0.0      12.3           11           48.0
# 6050     18.4     28.9       0.0      13.0            8           37.0
# 6052     19.4     37.6       0.0      10.6            5           46.0
# 6053     21.9     38.4       0.0      12.2           14           31.0
# 6054     24.2     41.0       0.0       8.4           14           35.0
#
#       WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 6049           1          12           6.0          20.0         20.0
# 6050          10          10          19.0          19.0         30.0
# 6052           5           6          30.0          15.0         42.0
# 6053          14          15           6.0           6.0         37.0
# 6054           7          14          17.0          13.0         19.0
#
#       Humidity3pm  Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#divide datainto dependent and independent data. Updating x and y.
x=df.drop(['RainTomorrow'],axis=1)  #dependent column. 
y=df['RainTomorrow']       #need to be predicted.

# %%
#lets check in x last column is not in cluded
x.head()
# Out:
#       MinTemp  MaxTemp  Rainfall  Sunshine  WindGustDir  WindGustSpeed  \
# 6049     17.9     35.2       0.0      12.3           11           48.0
# 6050     18.4     28.9       0.0      13.0            8           37.0
# 6052     19.4     37.6       0.0      10.6            5           46.0
# 6053     21.9     38.4       0.0      12.2           14           31.0
# 6054     24.2     41.0       0.0       8.4           14           35.0
#
#       WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 6049           1          12           6.0          20.0         20.0
# 6050          10          10          19.0          19.0         30.0
# 6052           5           6          30.0          15.0         42.0
# 6053          14          15           6.0           6.0         37.0
# 6054           7          14          17.0          13.0         19.0
#
#       Humidity3pm  Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday
# ...

# %%
#as min temp is incresing the max temp is increasing so it is leanear form
plt.figure(figsize=(15,10)) #size of the fig
sns.scatterplot(x='MaxTemp', y='MinTemp',hue='RainTomorrow',palette='bright',data=df) #maxtemp vs mintemp plot on scatterplt.
# Out:
# <AxesSubplot:xlabel='MaxTemp', ylabel='MinTemp'>

# %%
#plot regarding humidity and temp.
plt.figure(figsize=(15,10))
sns.scatterplot(x='Humidity9am', y='Temp9am', hue='RainTomorrow',palette='colorblind',data=df)
# Out:
# <AxesSubplot:xlabel='Humidity9am', ylabel='Temp9am'>

# %%
#heatmap to show the corellation of rain tmrw.
#good realtionship with humidity9am and humidity3pm. and raintoday also.
plt.figure(figsize=(15,10))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split #imported train test to split data.
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3) #30% of data from the dataset.

# %%
from sklearn.metrics import accuracy_score

# %%
#logistic regresstion.
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()   #creating object of it.
lr.fit(x_train,y_train)   #fitting xtrain and ytrain.
predictions=lr.predict(x_test)  #what to be predicted.
print(accuracy_score(y_test,predictions))  #accuracy is 85%
# Out:
# 0.850555166549965
# C:\Users\ujjwa\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#imported required libraries. CSV file also
import pandas as pd     
import numpy as np    
import seaborn as sns  
import matplotlib.pyplot as plt 
# %matplotlib inline

df = pd.read_csv('AustraliaWeather.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#shape of the dataset
df.shape
# Out:
# (145460, 23)

# %%
#first 5 rows of the dataset
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#returns the number of missing values in each column
df.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
#dropping all null values and shape of the dataset
df = df.dropna()
df.shape
# Out:
# (56420, 23)

# %%
#returns the number of missing values in each column
df.isna().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
#getting data in the particular area.
df = df[df['Location']=='Darwin']
df.shape
del df['Location']

# %%
#information of the current dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3062 entries, 139111 to 142302
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3062 non-null   object
#  1   MinTemp        3062 non-null   float64
#  2   MaxTemp        3062 non-null   float64
#  3   Rainfall       3062 non-null   float64
#  4   Evaporation    3062 non-null   float64
#  5   Sunshine       3062 non-null   float64
#  6   WindGustDir    3062 non-null   object
#  7   WindGustSpeed  3062 non-null   float64
#  8   WindDir9am     3062 non-null   object
#  9   WindDir3pm     3062 non-null   object
#  10  WindSpeed9am   3062 non-null   float64
#  11  WindSpeed3pm   3062 non-null   float64
#  12  Humidity9am    3062 non-null   float64
#  13  Humidity3pm    3062 non-null   float64
#  14  Pressure9am    3062 non-null   float64
#  15  Pressure3pm    3062 non-null   float64
#  16  Cloud9am       3062 non-null   float64
# ...

# %%
#description of the current dataset
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  3062.000000  3062.000000  3062.000000  3062.000000  3062.000000
# mean     23.166492    32.559536     4.038210     6.318746     8.596571
# std       2.986763     1.720600    11.166785     1.855733     3.120268
# min      12.500000    21.900000     0.000000     0.200000     0.000000
# 25%      21.500000    31.600000     0.000000     5.200000     7.200000
# 50%      23.900000    32.800000     0.000000     6.400000    10.000000
# 75%      25.275000    33.700000     1.400000     7.600000    10.900000
# max      29.700000    38.000000   132.600000    16.800000    12.300000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    3062.000000   3062.000000   3062.000000  3062.000000  3062.000000
# mean       40.429784     15.134226     20.847485    68.111039    51.338668
# std         9.694524      6.689497      5.970902    14.977848    18.505584
# ...

# %%
#data visualization. 
#getting month from date.
def get_month(date):  #get the particular column which we want
    return int(date.split('-')[1]) #split the date
df = df.rename(columns={'Date': 'Month'})   #rename colum to month 
df['Month'] = df['Month'].apply(get_month) #keep only month in column month.

# %%
#month colum added in the dataset
df.head()
# Out:
#         Month  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 139111      7     20.0     33.1       0.0          4.4      11.0           E
# 139112      7     19.4     32.4       0.0          6.0      10.4         ENE
# 139113      7     18.2     31.8       0.0          8.0      11.0           E
# 139114      7     17.3     30.7       0.0          7.0      10.4           E
# 139115      7     15.5     30.8       0.0          7.0      10.8         ESE
#
#         WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 139111           41.0        ENE        SSE  ...         81.0         32.0
# 139112           50.0         SE          E  ...         81.0         17.0
# 139113           46.0        ESE        ENE  ...         38.0         24.0
# 139114           44.0         SE          E  ...         55.0         16.0
# 139115           46.0          E          E  ...         37.0         16.0
#
# ...

# %%
#over all rain according to month.
#plt.figure(figsize=(10,5))
sns.countplot(data = df, x='Month', hue = df['RainTomorrow'])
plt.show()

# %%
#it will rain tmrw depend on rain today prediction
plt.figure(figsize=(10,5))
sns.countplot(data = df, x = 'RainToday', hue=df['RainTomorrow']);

# %%
#rain tmrw or not according to windgustdir
plt.figure(figsize=(10,5))
sns.countplot(data = df, x = 'WindGustDir', hue=df['RainTomorrow']);

# %%
#rain tmrw as per the wind at 3pm
plt.figure(figsize=(10,5))
sns.countplot(data = df, x = 'WindDir3pm', hue=df['RainTomorrow']);

# %%
#rain tmrw as per the wind at 9am
plt.figure(figsize=(10,5))
sns.countplot(data = df, x = 'WindDir9am', hue=df['RainTomorrow']);

# %%
#max temp vs min temp. as temp will decrease it will rain else no.
plt.figure(figsize=(10,5))
sns.scatterplot(x='MaxTemp', y='MinTemp', data=df, hue='RainTomorrow');
