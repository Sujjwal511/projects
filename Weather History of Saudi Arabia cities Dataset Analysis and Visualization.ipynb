# %%
'''
COMMON OBJECTIVE---------
    1) Analyse the dataset given by the customer.
    2) Check wether the dataset contains any null values or not.
        if yes- remove all null values or replace null values by using central tendency variation.
        if not - you can proceed with the same dataset.
    3) Check all the columns data-values is correctly formatted to their column name.
PROJECT OBJECTIVE--------
    4) find unique cities which as max temp and represent on graphically. 
    5) find unique cities which has max wind and represent on graphically.

'''
# Out:
# '\nCOMMON OBJECTIVE---------\n    1) Analyse the dataset given by the customer.\n    2) Check wether the dataset contains any null values or not.\n        if yes- remove all null values or replace null values by using central tendency variation.\n        if not - you can proceed with the same dataset.\n    3) Check all the columns data-values is correctly formatted to their column name.\nPROJECT OBJECTIVE--------\n    4) find the 5 cities which as max temp and represent on graph. \n\n'

# %%
#find unique cities which as max temp and represent on graphically.
import pandas as pd    #importing pandas lib
import numpy as np     #importing numpy lib
import seaborn as sns  
import matplotlib.pyplot as plt 
# %matplotlib inline

#reading CSV file 
df = pd.read_csv('SaudiWeather.csv')
df
# Out:
#           city       date   time  year  month  day  hour  minute  \
# 0       Qassim  01-Jan-17  00:00  2017      1    1    24       0
# 1       Qassim  01-Jan-17  01:00  2017      1    1     1       0
# 2       Qassim  01-Jan-17  03:00  2017      1    1     3       0
# 3       Qassim  01-Jan-17  04:00  2017      1    1     4       0
# 4       Qassim  01-Jan-17  05:00  2017      1    1     5       0
# ...        ...        ...    ...   ...    ...  ...   ...     ...
# 249018    Jawf  30-Apr-19  19:00  2019      4   30    19       0
# 249019    Jawf  30-Apr-19  20:00  2019      4   30    20       0
# 249020    Jawf  30-Apr-19  21:00  2019      4   30    21       0
# 249021    Jawf  30-Apr-19  22:00  2019      4   30    22       0
# 249022    Jawf  30-Apr-19  23:00  2019      4   30    23       0
#
#                 weather  temp  wind humidity  barometer  visibility
# 0                Clear     17    11      64%       1018          16
# ...

# %%
#full information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249023 entries, 0 to 249022
# Data columns (total 14 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   city        249023 non-null  object
#  1   date        249023 non-null  object
#  2   time        249023 non-null  object
#  3   year        249023 non-null  int64
#  4   month       249023 non-null  int64
#  5   day         249023 non-null  int64
#  6   hour        249023 non-null  int64
#  7   minute      249023 non-null  int64
#  8   weather     249023 non-null  object
#  9   temp        249023 non-null  int64
#  10  wind        249023 non-null  int64
#  11  humidity    249023 non-null  object
#  12  barometer   249023 non-null  int64
#  13  visibility  249023 non-null  int64
# dtypes: int64(9), object(5)
# memory usage: 26.6+ MB

# %%
#check for null values
df.isnull()
# Out:
#          city   date   time   year  month    day   hour  minute  weather  \
# 0       False  False  False  False  False  False  False   False    False
# 1       False  False  False  False  False  False  False   False    False
# 2       False  False  False  False  False  False  False   False    False
# 3       False  False  False  False  False  False  False   False    False
# 4       False  False  False  False  False  False  False   False    False
# ...       ...    ...    ...    ...    ...    ...    ...     ...      ...
# 249018  False  False  False  False  False  False  False   False    False
# 249019  False  False  False  False  False  False  False   False    False
# 249020  False  False  False  False  False  False  False   False    False
# 249021  False  False  False  False  False  False  False   False    False
# 249022  False  False  False  False  False  False  False   False    False
#
#          temp   wind  humidity  barometer  visibility
# ...

# %%
#sum of ull values column wise
df.isnull().sum()
# Out:
# city          0
# date          0
# time          0
# year          0
# month         0
# day           0
# hour          0
# minute        0
# weather       0
# temp          0
# wind          0
# humidity      0
# barometer     0
# visibility    0
# dtype: int64

# %%
#head to print first 5 rows with all columns in dataset. by defalult it takes 5
df.head()
# Out:
#      city       date   time  year  month  day  hour  minute weather  temp  \
# 0  Qassim  01-Jan-17  00:00  2017      1    1    24       0  Clear     17
# 1  Qassim  01-Jan-17  01:00  2017      1    1     1       0  Clear     17
# 2  Qassim  01-Jan-17  03:00  2017      1    1     3       0  Clear     15
# 3  Qassim  01-Jan-17  04:00  2017      1    1     4       0  Clear     15
# 4  Qassim  01-Jan-17  05:00  2017      1    1     5       0  Clear     15
#
#    wind humidity  barometer  visibility
# 0    11      64%       1018          16
# 1     6      64%       1018          16
# 2    11      72%       1019          16
# 3    11      72%       1019          16
# 4     9      72%       1019          16

# %%
#tail to print last 5 rows with all columns in data set. by defalult it takes 5
df.tail()
# Out:
#         city       date   time  year  month  day  hour  minute  \
# 249018  Jawf  30-Apr-19  19:00  2019      4   30    19       0
# 249019  Jawf  30-Apr-19  20:00  2019      4   30    20       0
# 249020  Jawf  30-Apr-19  21:00  2019      4   30    21       0
# 249021  Jawf  30-Apr-19  22:00  2019      4   30    22       0
# 249022  Jawf  30-Apr-19  23:00  2019      4   30    23       0
#
#                 weather  temp  wind humidity  barometer  visibility
# 249018  Passing clouds     32    19      14%       1014          -1
# 249019  Passing clouds     29     9      22%       1015          -1
# 249020  Passing clouds     27     7      24%       1016          -1
# 249021           Clear     26     0      26%       1017          16
# 249022           Clear     24     7      29%       1017          16

# %%
#description of the dataset and transpose of it.
df.describe().T
# Out:
#                count         mean       std     min     25%     50%     75%  \
# year        249023.0  2017.710007  0.706113  2017.0  2017.0  2018.0  2018.0
# month       249023.0     6.050694  3.521591     1.0     3.0     6.0     9.0
# day         249023.0    15.691081  8.787958     1.0     8.0    16.0    23.0
# hour        249023.0    12.536890  6.910254     1.0     7.0    13.0    19.0
# minute      249023.0     0.131108  1.970710     0.0     0.0     0.0     0.0
# temp        249023.0    24.722624  8.880913    -4.0    18.0    24.0    31.0
# wind        249023.0    12.957104  8.711619    -1.0     7.0    11.0    19.0
# barometer   249023.0  1015.453826  6.970637   904.0  1011.0  1016.0  1021.0
# visibility  249023.0    11.053453  7.053005    -1.0     5.0    16.0    16.0
#
#                max
# year        2019.0
# month         12.0
# day           31.0
# hour          24.0
# minute        59.0
# temp          50.0
# wind         163.0
# barometer   1101.0
# visibility   161.0

# %%
#shape of the dataset.
df.shape
# Out:
# (249023, 14)

# %%
#number of element in the dataset.
df.size
# Out:
# 3486322

# %%
#Temperature greater than 20
(df['temp'] > 20).value_counts()
# Out:
# True     163008
# False     86015
# Name: temp, dtype: int64

# %%
#sorting data set into ascending order.
print('sorting data set into ascending order.-----------------------------------------------')
city=df.sort_values(by='city', ascending = True)
city
# Out:
# sorting data set into ascending order.-----------------------------------------------
#          city       date   time  year  month  day  hour  minute  \
# 135313  Assir  01-Jan-17  00:00  2017      1    1    24       0
# 144299  Assir  20-Oct-18  18:00  2018     10   20    18       0
# 144300  Assir  20-Oct-18  19:00  2018     10   20    19       0
# 144301  Assir  20-Oct-18  20:00  2018     10   20    20       0
# 144302  Assir  20-Oct-18  21:00  2018     10   20    21       0
# ...       ...        ...    ...   ...    ...  ...   ...     ...
# 121816  Tabuk  10-Oct-17  13:00  2017     10   10    13       0
# 121815  Tabuk  10-Oct-17  12:00  2017     10   10    12       0
# 121814  Tabuk  10-Oct-17  11:00  2017     10   10    11       0
# 121821  Tabuk  10-Oct-17  18:00  2017     10   10    18       0
# 124511  Tabuk  01-Feb-18  02:00  2018      2    1     2       0
#
#                 weather  temp  wind humidity  barometer  visibility
# ...

# %%
#Dropping the duplicates values in the data set
print('Dropping the duplicates values in the data set---------------------------------------')
place = city['city'].drop_duplicates()
place
# Out:
# Dropping the duplicates values in the data set---------------------------------------
# 135313               Assir
# 222199                Baha
# 66046                   EP
# 20302                 Hail
# 242430                Jawf
# 176436               Jazan
# 58605               Madina
# 96284                Mecca
# 195661              Najran
# 150162    Northern boarder
# 0                   Qassim
# 84303               Riyadh
# 135311               Tabuk
# Name: city, dtype: object

# %%
#group the dataset relate to city column
print('group the dataset relate to city column----------------------------------------------')
CITY=df.groupby('city')
CITY.first()
# Out:
# group the dataset relate to city column----------------------------------------------
#                        date   time  year  month  day  hour  minute  \
# city
# Assir             01-Jan-17  00:00  2017      1    1    24       0
# Baha              01-Jan-17  00:00  2017      1    1    24       0
# EP                01-Jan-17  00:00  2017      1    1    24       0
# Hail              01-Jan-17  00:00  2017      1    1    24       0
# Jawf              01-Jan-17  00:00  2017      1    1    24       0
# Jazan             01-Jan-17  00:00  2017      1    1    24       0
# Madina            01-Jan-17  00:00  2017      1    1    24       0
# Mecca             01-Jan-17  00:00  2017      1    1    24       0
# Najran            01-Jan-17  00:00  2017      1    1    24       0
# Northern boarder  01-Jan-17  00:00  2017      1    1    24       0
# Qassim            01-Jan-17  00:00  2017      1    1    24       0
# Riyadh            23-Mar-17  20:00  2017      3   23    20       0
# ...

# %%
#find the max temp for the city
print('Finding the maximum temperature for the city')
temp=CITY.agg({'temp':['max']})
temp
# Out:
# Finding the maximum temperature for the city
#                  temp
#                   max
# city
# Assir              35
# Baha               39
# EP                 50
# Hail               48
# Jawf               46
# Jazan              37
# Madina             47
# Mecca              49
# Najran             37
# Northern boarder   47
# Qassim             48
# Riyadh             47
# Tabuk              45

# %%
#sort values in desc order of top 5 cities which have max temp
print('Top cities which has max temperature-----------------------------------------------')
temp_max=temp.sort_values(by=[('temp','max')],ascending=False)
temp_max
# Out:
# Top 5 cities which has max temperature-----------------------------------------------
#                  temp
#                   max
# city
# EP                 50
# Mecca              49
# Hail               48
# Qassim             48
# Madina             47
# Northern boarder   47
# Riyadh             47
# Jawf               46
# Tabuk              45
# Baha               39
# Jazan              37
# Najran             37
# Assir              35

# %%
#plotted the all cities with its max temp
temp_max.plot(kind='bar', figsize=(15,10), color='red')
plt.title("All cities VS maximum temperature", size = 18)
plt.xticks(rotation=90)
plt.xlabel("City")
plt.ylabel("Maximum Temperature")
# Out:
# Text(0, 0.5, 'Maximum Temperature')

# %%
#find unique cities which has max wind and represent on graphically.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

#reading CSV file 
df = pd.read_csv('SaudiWeather.csv')
df
# Out:
#           city       date   time  year  month  day  hour  minute  \
# 0       Qassim  01-Jan-17  00:00  2017      1    1    24       0
# 1       Qassim  01-Jan-17  01:00  2017      1    1     1       0
# 2       Qassim  01-Jan-17  03:00  2017      1    1     3       0
# 3       Qassim  01-Jan-17  04:00  2017      1    1     4       0
# 4       Qassim  01-Jan-17  05:00  2017      1    1     5       0
# ...        ...        ...    ...   ...    ...  ...   ...     ...
# 249018    Jawf  30-Apr-19  19:00  2019      4   30    19       0
# 249019    Jawf  30-Apr-19  20:00  2019      4   30    20       0
# 249020    Jawf  30-Apr-19  21:00  2019      4   30    21       0
# 249021    Jawf  30-Apr-19  22:00  2019      4   30    22       0
# 249022    Jawf  30-Apr-19  23:00  2019      4   30    23       0
#
#                 weather  temp  wind humidity  barometer  visibility
# 0                Clear     17    11      64%       1018          16
# ...

# %%
#full information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249023 entries, 0 to 249022
# Data columns (total 14 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   city        249023 non-null  object
#  1   date        249023 non-null  object
#  2   time        249023 non-null  object
#  3   year        249023 non-null  int64
#  4   month       249023 non-null  int64
#  5   day         249023 non-null  int64
#  6   hour        249023 non-null  int64
#  7   minute      249023 non-null  int64
#  8   weather     249023 non-null  object
#  9   temp        249023 non-null  int64
#  10  wind        249023 non-null  int64
#  11  humidity    249023 non-null  object
#  12  barometer   249023 non-null  int64
#  13  visibility  249023 non-null  int64
# dtypes: int64(9), object(5)
# memory usage: 26.6+ MB

# %%
#check for null values
df.isnull()
# Out:
#          city   date   time   year  month    day   hour  minute  weather  \
# 0       False  False  False  False  False  False  False   False    False
# 1       False  False  False  False  False  False  False   False    False
# 2       False  False  False  False  False  False  False   False    False
# 3       False  False  False  False  False  False  False   False    False
# 4       False  False  False  False  False  False  False   False    False
# ...       ...    ...    ...    ...    ...    ...    ...     ...      ...
# 249018  False  False  False  False  False  False  False   False    False
# 249019  False  False  False  False  False  False  False   False    False
# 249020  False  False  False  False  False  False  False   False    False
# 249021  False  False  False  False  False  False  False   False    False
# 249022  False  False  False  False  False  False  False   False    False
#
#          temp   wind  humidity  barometer  visibility
# ...

# %%
#sum of ull values column wise
df.isnull().sum()
# Out:
# city          0
# date          0
# time          0
# year          0
# month         0
# day           0
# hour          0
# minute        0
# weather       0
# temp          0
# wind          0
# humidity      0
# barometer     0
# visibility    0
# dtype: int64

# %%
#head to print first 5 rows with all columns in dataset. by defalult it takes 5
df.head()
# Out:
#      city       date   time  year  month  day  hour  minute weather  temp  \
# 0  Qassim  01-Jan-17  00:00  2017      1    1    24       0  Clear     17
# 1  Qassim  01-Jan-17  01:00  2017      1    1     1       0  Clear     17
# 2  Qassim  01-Jan-17  03:00  2017      1    1     3       0  Clear     15
# 3  Qassim  01-Jan-17  04:00  2017      1    1     4       0  Clear     15
# 4  Qassim  01-Jan-17  05:00  2017      1    1     5       0  Clear     15
#
#    wind humidity  barometer  visibility
# 0    11      64%       1018          16
# 1     6      64%       1018          16
# 2    11      72%       1019          16
# 3    11      72%       1019          16
# 4     9      72%       1019          16

# %%
#tail to print last 5 rows with all columns in data set. by defalult it takes 5
df.tail()
# Out:
#         city       date   time  year  month  day  hour  minute  \
# 249018  Jawf  30-Apr-19  19:00  2019      4   30    19       0
# 249019  Jawf  30-Apr-19  20:00  2019      4   30    20       0
# 249020  Jawf  30-Apr-19  21:00  2019      4   30    21       0
# 249021  Jawf  30-Apr-19  22:00  2019      4   30    22       0
# 249022  Jawf  30-Apr-19  23:00  2019      4   30    23       0
#
#                 weather  temp  wind humidity  barometer  visibility
# 249018  Passing clouds     32    19      14%       1014          -1
# 249019  Passing clouds     29     9      22%       1015          -1
# 249020  Passing clouds     27     7      24%       1016          -1
# 249021           Clear     26     0      26%       1017          16
# 249022           Clear     24     7      29%       1017          16

# %%
#description of the dataset.
df.describe()
# Out:
#                 year          month            day           hour  \
# count  249023.000000  249023.000000  249023.000000  249023.000000
# mean     2017.710007       6.050694      15.691081      12.536890
# std         0.706113       3.521591       8.787958       6.910254
# min      2017.000000       1.000000       1.000000       1.000000
# 25%      2017.000000       3.000000       8.000000       7.000000
# 50%      2018.000000       6.000000      16.000000      13.000000
# 75%      2018.000000       9.000000      23.000000      19.000000
# max      2019.000000      12.000000      31.000000      24.000000
#
#               minute           temp           wind      barometer  \
# count  249023.000000  249023.000000  249023.000000  249023.000000
# mean        0.131108      24.722624      12.957104    1015.453826
# std         1.970710       8.880913       8.711619       6.970637
# min         0.000000      -4.000000      -1.000000     904.000000
# ...

# %%
#shape of the dataset.
df.shape
# Out:
# (249023, 14)

# %%
#number of element in the dataset.
df.size
# Out:
# 3486322

# %%
#dataset index
df.index
# Out:
# RangeIndex(start=0, stop=249023, step=1)

# %%
#unique from weather column. List of unique weather names.
df['weather'].unique()
# Out:
# array(['Clear ', 'Sunny ', 'Scattered clouds ', 'Partly sunny ',
#        'Passing clouds ', 'Refreshingly cool ', 'Low level haze ',
#        'Duststorm ', 'Thunderstorms  Passing clouds ', 'Fog ',
#        'Thunderstorms  Partly sunny ', 'Light rain  Partly sunny ',
#        'Dense fog ', 'Thunderstorms  Scattered clouds ',
#        'Rain  Passing clouds ', 'Extremely hot ', 'Rain  Partly sunny ',
#        'Pleasantly warm ', 'Hot ', 'Mild ', 'Overcast ',
#        'Rain  Overcast ', 'Smoke ', 'Thunderstorms  Broken clouds ',
#        'Heavy rain  Partly sunny ', 'Thunderstorms  Overcast ',
#        'Light rain  Overcast ', 'Warm ', 'Thunderstorms  Cloudy ',
#        'Drizzle  Overcast ', 'Thunderstorms  Partly cloudy ',
#        'Broken clouds ', 'Sandstorm ', 'Partly cloudy ', 'Mostly cloudy ',
#        'Rain  Partly cloudy ', 'Rain  Broken clouds ',
#        'Rain  Scattered clouds ', 'Haze ', 'Rain  Mostly cloudy ',
# ...

# %%
#sorting data set into ascending order.
print('sorting data set into ascending order.-----------------------------------------------')
city=df.sort_values(by='city', ascending = True)
city
# Out:
# sorting data set into ascending order.-----------------------------------------------
#          city       date   time  year  month  day  hour  minute  \
# 135313  Assir  01-Jan-17  00:00  2017      1    1    24       0
# 144299  Assir  20-Oct-18  18:00  2018     10   20    18       0
# 144300  Assir  20-Oct-18  19:00  2018     10   20    19       0
# 144301  Assir  20-Oct-18  20:00  2018     10   20    20       0
# 144302  Assir  20-Oct-18  21:00  2018     10   20    21       0
# ...       ...        ...    ...   ...    ...  ...   ...     ...
# 121816  Tabuk  10-Oct-17  13:00  2017     10   10    13       0
# 121815  Tabuk  10-Oct-17  12:00  2017     10   10    12       0
# 121814  Tabuk  10-Oct-17  11:00  2017     10   10    11       0
# 121821  Tabuk  10-Oct-17  18:00  2017     10   10    18       0
# 124511  Tabuk  01-Feb-18  02:00  2018      2    1     2       0
#
#                 weather  temp  wind humidity  barometer  visibility
# ...

# %%
#Dropping the duplicates values in the data set
print('Dropping the duplicates values in the data set---------------------------------------')
place1 = city['city'].drop_duplicates()
place1
# Out:
# Dropping the duplicates values in the data set---------------------------------------
# 135313               Assir
# 222199                Baha
# 66046                   EP
# 20302                 Hail
# 242430                Jawf
# 176436               Jazan
# 58605               Madina
# 96284                Mecca
# 195661              Najran
# 150162    Northern boarder
# 0                   Qassim
# 84303               Riyadh
# 135311               Tabuk
# Name: city, dtype: object

# %%
#group the dataset relate to city column
print('group the dataset relate to city column----------------------------------------------')
CITY=df.groupby('city')
CITY.first()
# Out:
# group the dataset relate to city column----------------------------------------------
#                        date   time  year  month  day  hour  minute  \
# city
# Assir             01-Jan-17  00:00  2017      1    1    24       0
# Baha              01-Jan-17  00:00  2017      1    1    24       0
# EP                01-Jan-17  00:00  2017      1    1    24       0
# Hail              01-Jan-17  00:00  2017      1    1    24       0
# Jawf              01-Jan-17  00:00  2017      1    1    24       0
# Jazan             01-Jan-17  00:00  2017      1    1    24       0
# Madina            01-Jan-17  00:00  2017      1    1    24       0
# Mecca             01-Jan-17  00:00  2017      1    1    24       0
# Najran            01-Jan-17  00:00  2017      1    1    24       0
# Northern boarder  01-Jan-17  00:00  2017      1    1    24       0
# Qassim            01-Jan-17  00:00  2017      1    1    24       0
# Riyadh            23-Mar-17  20:00  2017      3   23    20       0
# ...

# %%
#find the max wind for the cities
print('Finding the maximum wind for the cities')
wind=CITY.agg({'wind':['max']})
wind
# Out:
# Finding the maximum wind for the cities
#                  wind
#                   max
# city
# Assir              59
# Baha               65
# EP                 65
# Hail               93
# Jawf               80
# Jazan              59
# Madina             76
# Mecca             163
# Najran             59
# Northern boarder   70
# Qassim             93
# Riyadh             61
# Tabuk             115

# %%
#plotted the all cities with its max temp
wind.plot(kind='barh', figsize=(15,10), color='skyblue')
plt.title("All cities VS Maximum Wind")
plt.xlabel("Maximum Wind")
plt.ylabel("City")
# Out:
# Text(0, 0.5, 'City')

# %%
import pandas as pd    #importing pandas lib
import numpy as np     #importing numpy lib
import seaborn as sns  
import matplotlib.pyplot as plt 
# %matplotlib inline

#reading CSV file 
df = pd.read_csv('SaudiWeather.csv')
df
# Out:
#           city       date   time  year  month  day  hour  minute  \
# 0       Qassim  01-Jan-17  00:00  2017      1    1    24       0
# 1       Qassim  01-Jan-17  01:00  2017      1    1     1       0
# 2       Qassim  01-Jan-17  03:00  2017      1    1     3       0
# 3       Qassim  01-Jan-17  04:00  2017      1    1     4       0
# 4       Qassim  01-Jan-17  05:00  2017      1    1     5       0
# ...        ...        ...    ...   ...    ...  ...   ...     ...
# 249018    Jawf  30-Apr-19  19:00  2019      4   30    19       0
# 249019    Jawf  30-Apr-19  20:00  2019      4   30    20       0
# 249020    Jawf  30-Apr-19  21:00  2019      4   30    21       0
# 249021    Jawf  30-Apr-19  22:00  2019      4   30    22       0
# 249022    Jawf  30-Apr-19  23:00  2019      4   30    23       0
#
#                 weather  temp  wind humidity  barometer  visibility
# 0                Clear     17    11      64%       1018          16
# ...

# %%
df.head()
# Out:
#      city       date   time  year  month  day  hour  minute weather  temp  \
# 0  Qassim  01-Jan-17  00:00  2017      1    1    24       0  Clear     17
# 1  Qassim  01-Jan-17  01:00  2017      1    1     1       0  Clear     17
# 2  Qassim  01-Jan-17  03:00  2017      1    1     3       0  Clear     15
# 3  Qassim  01-Jan-17  04:00  2017      1    1     4       0  Clear     15
# 4  Qassim  01-Jan-17  05:00  2017      1    1     5       0  Clear     15
#
#    wind humidity  barometer  visibility
# 0    11      64%       1018          16
# 1     6      64%       1018          16
# 2    11      72%       1019          16
# 3    11      72%       1019          16
# 4     9      72%       1019          16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249023 entries, 0 to 249022
# Data columns (total 14 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   city        249023 non-null  object
#  1   date        249023 non-null  object
#  2   time        249023 non-null  object
#  3   year        249023 non-null  int64
#  4   month       249023 non-null  int64
#  5   day         249023 non-null  int64
#  6   hour        249023 non-null  int64
#  7   minute      249023 non-null  int64
#  8   weather     249023 non-null  object
#  9   temp        249023 non-null  int64
#  10  wind        249023 non-null  int64
#  11  humidity    249023 non-null  object
#  12  barometer   249023 non-null  int64
#  13  visibility  249023 non-null  int64
# dtypes: int64(9), object(5)
# memory usage: 26.6+ MB

# %%
#convert humidity to numerical
df['humidity'] = df['humidity'].str.replace('%',' ').astype('float')

# %%
df.isnull().sum()
# Out:
# city          0
# date          0
# time          0
# year          0
# month         0
# day           0
# hour          0
# minute        0
# weather       0
# temp          0
# wind          0
# humidity      0
# barometer     0
# visibility    0
# dtype: int64

# %%
#mean as per city
df.groupby(by='city')[['humidity','barometer']].mean().reset_index()
# Out:
#                 city   humidity    barometer
# 0              Assir  47.590154  1023.498147
# 1               Baha  38.722982  1019.011874
# 2                 EP  45.092191  1008.609943
# 3               Hail  41.532826  1013.527161
# 4               Jawf  30.499410  1015.506093
# 5              Jazan  45.803066  1023.087145
# 6             Madina  19.971600  1014.140997
# 7              Mecca  54.158772  1008.713933
# 8             Najran  45.953645  1023.093818
# 9   Northern boarder  26.263800  1012.642254
# 10            Qassim  41.475168  1013.489062
# 11            Riyadh  24.087936  1013.289995
# 12             Tabuk  28.718626  1014.266453

# %%
df.describe()
# Out:
#                 year          month            day           hour  \
# count  249023.000000  249023.000000  249023.000000  249023.000000
# mean     2017.710007       6.050694      15.691081      12.536890
# std         0.706113       3.521591       8.787958       6.910254
# min      2017.000000       1.000000       1.000000       1.000000
# 25%      2017.000000       3.000000       8.000000       7.000000
# 50%      2018.000000       6.000000      16.000000      13.000000
# 75%      2018.000000       9.000000      23.000000      19.000000
# max      2019.000000      12.000000      31.000000      24.000000
#
#               minute           temp           wind       humidity  \
# count  249023.000000  249023.000000  249023.000000  249023.000000
# mean        0.131108      24.722624      12.957104      37.552668
# std         1.970710       8.880913       8.711619      23.592876
# min         0.000000      -4.000000      -1.000000       0.000000
# ...

# %%
#unique weather
df['weather'].unique()
# Out:
# array(['Clear ', 'Sunny ', 'Scattered clouds ', 'Partly sunny ',
#        'Passing clouds ', 'Refreshingly cool ', 'Low level haze ',
#        'Duststorm ', 'Thunderstorms  Passing clouds ', 'Fog ',
#        'Thunderstorms  Partly sunny ', 'Light rain  Partly sunny ',
#        'Dense fog ', 'Thunderstorms  Scattered clouds ',
#        'Rain  Passing clouds ', 'Extremely hot ', 'Rain  Partly sunny ',
#        'Pleasantly warm ', 'Hot ', 'Mild ', 'Overcast ',
#        'Rain  Overcast ', 'Smoke ', 'Thunderstorms  Broken clouds ',
#        'Heavy rain  Partly sunny ', 'Thunderstorms  Overcast ',
#        'Light rain  Overcast ', 'Warm ', 'Thunderstorms  Cloudy ',
#        'Drizzle  Overcast ', 'Thunderstorms  Partly cloudy ',
#        'Broken clouds ', 'Sandstorm ', 'Partly cloudy ', 'Mostly cloudy ',
#        'Rain  Partly cloudy ', 'Rain  Broken clouds ',
#        'Rain  Scattered clouds ', 'Haze ', 'Rain  Mostly cloudy ',
# ...

# %%
#only related to rain weather we will store in rain var.
df['rain'] = df['weather'].str.contains('rain|shower|thunderstorm|thundershowers', case = False ,regex=True)
df
# Out:
#           city       date   time  year  month  day  hour  minute  \
# 0       Qassim  01-Jan-17  00:00  2017      1    1    24       0
# 1       Qassim  01-Jan-17  01:00  2017      1    1     1       0
# 2       Qassim  01-Jan-17  03:00  2017      1    1     3       0
# 3       Qassim  01-Jan-17  04:00  2017      1    1     4       0
# 4       Qassim  01-Jan-17  05:00  2017      1    1     5       0
# ...        ...        ...    ...   ...    ...  ...   ...     ...
# 249018    Jawf  30-Apr-19  19:00  2019      4   30    19       0
# 249019    Jawf  30-Apr-19  20:00  2019      4   30    20       0
# 249020    Jawf  30-Apr-19  21:00  2019      4   30    21       0
# 249021    Jawf  30-Apr-19  22:00  2019      4   30    22       0
# 249022    Jawf  30-Apr-19  23:00  2019      4   30    23       0
#
#                 weather  temp  wind  humidity  barometer  visibility   rain
# 0                Clear     17    11      64.0       1018          16  False
# ...

# %%
#check for sample all the weather type is under rain showing true or not.
df.groupby('weather')['rain'].unique().sample(20)
# Out:
# weather
# Thunderstorms  Fog                    [True]
# Light rain  Mostly cloudy             [True]
# Hail  Partly sunny                   [False]
# Drizzle  Dense fog                   [False]
# Thunderstorms  Partly sunny           [True]
# Heavy rain  More clouds than sun      [True]
# Fog                                  [False]
# Sprinkles  Cloudy                    [False]
# Sprinkles  Low level haze            [False]
# Sprinkles  Duststorm                 [False]
# Mild                                 [False]
# Strong thunderstorms  Cloudy          [True]
# Thunderstorms  Overcast               [True]
# More clouds than sun                 [False]
# Thunderstorms  Scattered clouds       [True]
# Drizzle  Overcast                    [False]
# Warm                                 [False]
# Light rain  Broken clouds             [True]
# Hot                                  [False]
# Partly sunny                         [False]
# Name: rain, dtype: object

# %%
#values count in rain var.
df['rain'].value_counts()
# Out:
# False    245696
# True       3327
# Name: rain, dtype: int64

# %%
#drop weather column as we dont need it not
df.drop('weather', axis =1 , inplace =True)
df
# Out:
#           city       date   time  year  month  day  hour  minute  temp  wind  \
# 0       Qassim  01-Jan-17  00:00  2017      1    1    24       0    17    11
# 1       Qassim  01-Jan-17  01:00  2017      1    1     1       0    17     6
# 2       Qassim  01-Jan-17  03:00  2017      1    1     3       0    15    11
# 3       Qassim  01-Jan-17  04:00  2017      1    1     4       0    15    11
# 4       Qassim  01-Jan-17  05:00  2017      1    1     5       0    15     9
# ...        ...        ...    ...   ...    ...  ...   ...     ...   ...   ...
# 249018    Jawf  30-Apr-19  19:00  2019      4   30    19       0    32    19
# 249019    Jawf  30-Apr-19  20:00  2019      4   30    20       0    29     9
# 249020    Jawf  30-Apr-19  21:00  2019      4   30    21       0    27     7
# 249021    Jawf  30-Apr-19  22:00  2019      4   30    22       0    26     0
# 249022    Jawf  30-Apr-19  23:00  2019      4   30    23       0    24     7
#
# ...

# %%
plt.figure(figsize=(15,10)) #size of the fig
sns.scatterplot(x='humidity', y='temp',hue='rain',palette='deep',data=df)
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='temp'>
